# %% [markdown]
# Objective 5

# %%
# OBJECTIVE_5_DEPLOYMENT.ipynb

import joblib
import pandas as pd
import numpy as np

# 1. Final Model Verification
# Ensure the model saved in Objective 3/4 loads correctly
try:
    model = joblib.load('cardio_model.pkl')
    print("Model loaded successfully!")
except Exception as e:
    print(f"Error loading model: {e}")
# Out:
# Model loaded successfully!

# %%
# 2. Define the Feature Order
# It is critical that the order of inputs matches the training data exactly
features = ['age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo', 
            'smoke', 'alco', 'active', 'cholesterol_2', 'cholesterol_3', 
            'gluc_2', 'gluc_3']

print(f"Expected input features: {features}")
# Out:
# Expected input features: ['age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo', 'smoke', 'alco', 'active', 'cholesterol_2', 'cholesterol_3', 'gluc_2', 'gluc_3']
